# %%
import covariance_learn
reload(covariance_learn)
import numpy as np
import matplotlib.pyplot as plt
import sparseprecision
# %matplotlib inline

# %%
graph_lasso = covariance_learn.GraphLasso(.3)
X = np.random.normal(size=(20, 100))
mask = graph_lasso.fit(X).precision_ != 0
ips = covariance_learn.IPS(mask)
plt.matshow(ips.fit(X).precision_)
hgl = covariance_learn.HierarchicalGraphLasso([[range(50)], [k+50 for k in range(50)]], .2)
hgl.fit(X)
# Out:
# [99]
# [50]
# [99]
# [51]
# [99]
# [52]
# [99]
# [53]
# [99]
# [54]
# [99]
# [55]
# [99]
# [56]
# [99]
# [57]
# [99]
# [58]
# [99]
# [59]
# [99]
# [60]
# [99]
# [61]
# [99]
# [62]
# [99]
# [63]
# [99]
# [64]
# [99]
# [65]
# [99]
# [66]
# [99]
# [67]
# [99]
# [68]
# [99]
# [69]
# [99]
# [70]
# [99]
# [71]
# [99]
# [72]
# [99]
# [73]
# [99]
# [74]
# [99]
# [75]
# [99]
# [76]
# [99]
# [77]
# [99]
# [78]
# [99]
# [79]
# [99]
# [80]
# [99]
# [81]
# [99]
# [82]
# [99]
# [83]
# [99]
# [84]
# [99]
# [85]
# [99]
# [86]
# [99]
# [87]
# [99]
# [88]
# [99]
# [89]
# [99]
# [90]
# [99]
# [91]
# [99]
# [92]
# [99]
# [93]
# [99]
# [94]
# [99]
# [95]
# [99]
# [96]
# [99]
# [97]
# [99]
# [98]
# [98]
# [50]
# [98]
# [51]
# [98]
# [52]
# [98]
# [53]
# [98]
# [54]
# [98]
# [55]
# [98]
# [56]
# [98]
# [57]
# [98]
# [58]
# [98]
# [59]
# [98]
# [60]
# [98]
# [61]
# [98]
# [62]
# [98]
# [63]
# [98]
# [64]
# [98]
# [65]
# [98]
# [66]
# [98]
# [67]
# [98]
# [68]
# [98]
# [69]
# [98]
# [70]
# [98]
# [71]
# ...

# %%
np.ix_?
